# %% [markdown]
# <a href="https://colab.research.google.com/github/NiveskZ/ETL-Alura/blob/main/pandas/desafios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Descrição
#
# Esse notebook foi construído para realizar os desafios propostos no final de cada aula do curso **Pandas: conhecendo a biblioteca**

# %% [markdown]
# ## Aula 1: Conhecendo a base de dados

# %% [markdown]
# ### Desafio 1
# Importe o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) e armazene seu conteúdo em um DataFrame Pandas

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
alunos_df = pd.read_csv(url)
alunos_df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 2
# Visualize as primeiras 7 linhas do DataFrame e as 5 últimas

# %%
alunos_df.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
alunos_df.tail()
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 3
# Confira a quantidade de linhas e colunas do DataFrame

# %%
alunos_df.shape
# Out:
# (18, 4)

# %% [markdown]
# ### Desafio 4
# Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna

# %%
alunos_df.columns
# Out:
# Index(['Nome', 'Idade', 'Notas', 'Aprovado'], dtype='object')

# %%
alunos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes

# %%
alunos_df.dtypes
# Out:
# Nome         object
# Idade         int64
# Notas       float64
# Aprovado       bool
# dtype: object

# %% [markdown]
# ### **Extra**
# Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc) - Dica: pesquise pelo método **describe**

# %%
alunos_df.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# ## Aula 2: Análise exploratória dos dados

# %% [markdown]
# Para os desafios dessa aula, vamos utilizar a mesma base de dados que estamos utilizando para o desenvolvimento do nosso projeto. Sendo assim, na célula abaixo vamos realizar a importação dessa base de dados e aplicar as transformações já realizadas até o momento da aula 2.

# %%
import pandas as pd

# %%
# importando a base de dados
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# removendo imóveis comerciais
df = dados.query('@imoveis_comerciais not in Tipo')

# selecionando apenas imóveis do tipo apartamento
df = df.query('Tipo == "Apartamento"')

# visualizando a base de dados
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# ### Desafio 1
# Calcular a média de quartos por apartamento

# %%
df['Quartos'].mean()
# Out:
# np.float64(2.481568707761622)

# %% [markdown]
# ### Desafio 2
# Conferir quantos bairros únicos existem na nossa base de dados

# %%
df.Bairro.unique().size
# Out:
# 149

# %%
df['Bairro'].nunique()
# Out:
# 149

# %% [markdown]
# ### Desafio 3
# Analisar quais bairros possuem a média de valor de aluguel mais elevadas

# %%
df.groupby('Bairro')[['Valor']].mean().sort_values('Valor',ascending=False)
# Out:
#                                Valor
# Bairro
# Joá                     15500.000000
# Arpoador                12429.769231
# Cidade Jardim           12000.000000
# Ipanema                  9487.205317
# Botafogo                 9369.207116
# ...                              ...
# Inhoaíba                  650.000000
# Cosmos                    610.000000
# Santa Cruz                590.000000
# Paciência                 510.000000
# Ricardo de Albuquerque    340.000000
#
# [149 rows x 1 columns]

# %% [markdown]
# ### Desafio 4
# Criar um gráfico de barras verticais que apresente os 5 bairros com a média de valor de aluguel mais elevadas

# %%
top5_bairros = df.groupby('Bairro')['Valor'].mean().sort_values(ascending=False).head(5)
top5_bairros.plot(kind='bar',figsize=(14,10), color='green', ylabel='Valor')
# Out:
# <Axes: xlabel='Bairro', ylabel='Valor'>

# %% [markdown]
# ## Aula 3
#
# Importe novamente o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) para realizar os desafios abaixo.

# %%
# Importando novamente os dados
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
alunos_df = pd.read_csv(url)
alunos_df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 1
# Verifique se a base de dados possui dados nulos e caso tenha, realize o tratamento desses dados nulos

# %%
alunos_df.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
# Como são notas de alunos, vamos supor que nota nula signifique que o aluno zerou a prova.
alunos_df.fillna(0, inplace=True)

# %%
alunos_df.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %% [markdown]
# ### Desafio 2
# Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados

# %%
alunos_df.Nome
# Out:
# 0           Ary
# 1           Ana
# 2         Cátia
# 3         Denis
# 4          Beto
# 5         Bruna
# 6          Dara
# 7        Carlos
# 8         Alice
# 9         Vitor
# 10       Daniel
# 11         Igor
# 12    Sthefanie
# 13        Mirla
# 14        Paulo
# 15       Mylena
# 16        Lucas
# 17        Nadia
# Name: Nome, dtype: object

# %%
alunos_removidos = alunos_df.query("Nome == 'Alice' | Nome == 'Carlos'").index
alunos_removidos
# Out:
# Index([7, 8], dtype='int64')

# %%
alunos_df.drop(alunos_removidos, axis=0, inplace=True)
alunos_df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    8.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 3
# Aplique um filtro que selecione apenas os alunos que foram aprovados

# %%
aprovados = alunos_df[alunos_df['Aprovado']]
aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 4
# Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv"

# %%
alunos_df.to_csv('alunos_aprovados.csv',index=False)

# %%
pd.read_csv('alunos_aprovados.csv')
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 7       Vitor     28    0.0     False
# 8      Daniel     21    0.0     False
# 9        Igor     24    4.5     False
# 10  Sthefanie     26    9.5      True
# 11      Mirla     25    9.0      True
# 12      Paulo     37    0.0     False
# 13     Mylena     29    8.0      True
# 14      Lucas     33    0.0     False
# 15      Nadia     34    8.0      True

# %% [markdown]
# ### **Extra**
# Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. **Dica**: pesquise pelo método **replace**

# %%
alunos_df.replace(7,8,inplace=True)

# %%
alunos_df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    8.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ## Aula 4
#
# Importe novamente o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) para realizar os desafios abaixo.

# %%
# Importando novamente os dados
# Importando novamente os dados
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
alunos_df = pd.read_csv(url)
alunos_df.head()
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %% [markdown]
# ### Desafio 1
# Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles

# %%
alunos_df['Notas'].fillna(0, inplace=True)
alunos_df['Pontos_extras'] = alunos_df['Notas'] * 0.40
alunos_df.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras
# 0    Ary     20    7.5      True            3.0
# 1    Ana     18    0.0     False            0.0
# 2  Cátia     27    2.5     False            1.0
# 3  Denis     18    5.0     False            2.0
# 4   Beto     21   10.0      True            4.0

# %% [markdown]
# ### Desafio 2
# Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras

# %%
alunos_df['Notas_finais'] = alunos_df.apply(lambda row: min(row['Pontos_extras'] + row['Notas'],10), axis=1)
alunos_df.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0    Ary     20    7.5      True            3.0          10.0
# 1    Ana     18    0.0     False            0.0           0.0
# 2  Cátia     27    2.5     False            1.0           3.5
# 3  Denis     18    5.0     False            2.0           7.0
# 4   Beto     21   10.0      True            4.0          10.0

# %% [markdown]
# ### Desafio 3
# Como os alunos ganharam pontos extras, alguns que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# * True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# * False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
alunos_df['Aprovados_final'] = alunos_df['Notas_finais'] >= 6
alunos_df.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  Aprovados_final
# 0    Ary     20    7.5      True            3.0          10.0             True
# 1    Ana     18    0.0     False            0.0           0.0            False
# 2  Cátia     27    2.5     False            1.0           3.5            False
# 3  Denis     18    5.0     False            2.0           7.0             True
# 4   Beto     21   10.0      True            4.0          10.0             True

# %% [markdown]
# ### Desafio 4
# Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras

# %%
alunos_df.query('Aprovado == False & Aprovados_final == True')
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 3   Denis     18    5.0     False           2.00          7.00
# 8   Alice     35    5.6     False           2.24          7.84
# 11   Igor     24    4.5     False           1.80          6.30
#
#     Aprovados_final
# 3              True
# 8              True
# 11             True
